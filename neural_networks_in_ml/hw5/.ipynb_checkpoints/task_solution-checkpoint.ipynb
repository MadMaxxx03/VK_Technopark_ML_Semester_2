# %% [markdown]
# ## Семинар 5: "Улучшение сходимости нейросетей"

# %% [markdown]
# ФИО: Бабенко Максим Денисович

# %%
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import torch
from torch import nn
import torch.nn.functional as F
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision.datasets import MNIST
from torchvision import transforms
# %matplotlib inline

# %% [markdown]
# ## Описание задания:
# Вам необходимо реализовать оставшиеся методы из лекции и сравнить их на примере из семинара.
#
# ## Задание разделено на следующие части:
# 1. Реализация Xavier **(1 балл)**
#
# 2.1 Реализация DropConnect **(1 балл)**
#
# 2.2 Сравнение обучения при использовании Dropout и DropConnect **(1 балл)**
#
# 3.1 Реализация LayerNorm **(1 балл)**
#
# 3.2 Сравнение обучения при использовании BatchNorm и LayerNorm **(1 балл)**
#
# ## Срок выполнения задания:
# Данное задание можно сдать без штрафов до 17 октября.

# %% [markdown]
# ### Часть 1: Инициализация весов

# %% [markdown]
# Будем использовать MNIST для обучения:

# %%
# Dataloader
to_numpy = lambda x: x.numpy()
transform = transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                    ])
train_dataset = MNIST('.', train=True, download=True, transform=transform)
test_dataset = MNIST('.', train=False, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=128, shuffle=True)

# %%
images_train, labels_train = next(iter(train_loader))

# %%
## Usage example:
for X, y in train_loader:
    X = X.view(X.size(0), -1)
    X = X.numpy() ### Converts torch.Tensor to numpy array
    y = y.numpy()
    break

# %%
plt.figure(figsize=(6, 7))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.imshow(X[i].reshape(28, 28), cmap=plt.cm.Greys_r)
    plt.title(y[i])
    plt.axis('off')

# %%
def init_layer(layer, mean=0, std=1):
    # Тут надо быть аккуратным — можно случайно создать копию и менять значения у копии
    weight = layer.state_dict()['weight']
    bias = layer.state_dict()['bias']
    bias.zero_()
    weight.normal_(mean=0, std=std)

def forward_hook(self, input_, output):
    std = input_[0].std().item()
    print('forward', std)

def backward_hook(self, grad_input, grad_output):
    std = grad_input[0].std().item()
    print('backward', std)

# %% [markdown]
# На вход передаем изображение 28x28, на выходе -- вероятности 10 классов.

# %%
layer_1 = nn.Linear(28*28, 500)
layer_2 = nn.Linear(500, 10)

layer_1.register_forward_hook(forward_hook)
layer_2.register_forward_hook(forward_hook)

layer_1.register_backward_hook(backward_hook)
layer_2.register_backward_hook(backward_hook)

init_layer(layer_1)
init_layer(layer_2)

# %% [markdown]
# Соберем все вместе, используя ReLU в качестве функции активации:

# %%
network = nn.Sequential(
    layer_1,
    nn.ReLU(),
    layer_2
)

# %%
n_objects = 100
X = images_train[:n_objects].view(n_objects, -1).data
y = labels_train[:n_objects].data
activations = network(X)
loss_fn = torch.nn.NLLLoss()
optimizer = torch.optim.Adam(network.parameters(), lr=0.001)
loss = loss_fn(activations, y)
loss.backward()
# Out:
# forward 0.9786878824234009
# forward 16.1044864654541
# backward 0.03464101627469063
# backward 0.1838112324476242
# C:\Users\baben_bakg1j1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1640: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)

# %% [markdown]
# #### 1.1 Реализуйте инициализацию Xavier. Сравните ее с He, которая была реализована на семинаре, сделайте выводы. Учтите, что для Xavier необходимо использовать функцию активации nn.Tanh(). **(1 балл)**
#
# ![image.png](data:image/png;base64,...)

# %%
def init_layer_xavier_uniform(layer):
    weight = layer.state_dict()['weight']
    bias = layer.state_dict()['bias']
    bias.zero_() 
    n_in, n_out = weight.size()
    limit = (6 / (n_in + n_out)) ** 0.5   
    weight.uniform_(-limit, limit)

# %%
#Xavier для сети с большим размером

layer_1 = nn.Linear(28 * 28, 1000) 
layer_2 = nn.Linear(1000, 500)      
layer_3 = nn.Linear(500, 200)       
layer_4 = nn.Linear(200, 10)        

layer_1.register_forward_hook(forward_hook)
layer_2.register_forward_hook(forward_hook)
layer_3.register_forward_hook(forward_hook)
layer_4.register_forward_hook(forward_hook)

layer_1.register_backward_hook(backward_hook)
layer_2.register_backward_hook(backward_hook)
layer_3.register_backward_hook(backward_hook)
layer_4.register_backward_hook(backward_hook)

init_layer_xavier_uniform(layer_1)
init_layer_xavier_uniform(layer_2)
init_layer_xavier_uniform(layer_3)
init_layer_xavier_uniform(layer_4)

network = nn.Sequential(
    layer_1,
    nn.Tanh(),
    layer_2,
    nn.Tanh(),
    layer_3,
    nn.Tanh(),
    layer_4
)

n_objects = 100
X = images_train[:n_objects].view(n_objects, -1).data
y = labels_train[:n_objects].data
activations = network(X)
loss_fn = torch.nn.NLLLoss()
optimizer = torch.optim.Adam(network.parameters(), lr=0.001)
loss = loss_fn(activations, y)
loss.backward()
# Out:
# forward 0.9786878824234009
# forward 0.5968003869056702
# forward 0.515407145023346
# forward 0.481207013130188
# backward 0.03464101627469063
# backward 0.02653743326663971
# backward 0.015344861894845963
# backward 0.00831416342407465

# %%
#He для сети с большим размером

layer_1 = nn.Linear(28 * 28, 1000)  
layer_2 = nn.Linear(1000, 500)     
layer_3 = nn.Linear(500, 200)       
layer_4 = nn.Linear(200, 10)        

layer_1.register_forward_hook(forward_hook)
layer_2.register_forward_hook(forward_hook)
layer_3.register_forward_hook(forward_hook)
layer_4.register_forward_hook(forward_hook)

layer_1.register_backward_hook(backward_hook)
layer_2.register_backward_hook(backward_hook)
layer_3.register_backward_hook(backward_hook)
layer_4.register_backward_hook(backward_hook)

init_layer(layer_1, 0, (2 / (28 * 28)) ** 0.5)
init_layer(layer_2, 0, (2 / 1000) ** 0.5)
init_layer(layer_3, 0, (2 / 500) ** 0.5)
init_layer(layer_4, 0, (2 / 200) ** 0.5)

network = nn.Sequential(
    layer_1,
    nn.ReLU(),
    layer_2,
    nn.ReLU(),
    layer_3,
    nn.ReLU(),
    layer_4
)

n_objects = 100
X = images_train[:n_objects].view(n_objects, -1).data
y = labels_train[:n_objects].data
activations = network(X)
loss_fn = torch.nn.NLLLoss()
optimizer = torch.optim.Adam(network.parameters(), lr=0.001)
loss = loss_fn(activations, y)
loss.backward()
# Out:
# forward 0.9786878824234009
# forward 0.8012264370918274
# forward 0.8276707530021667
# forward 0.8319458365440369
# backward 0.03464101627469063
# backward 0.02212117239832878
# backward 0.012358522042632103
# backward 0.007147905416786671

# %% [markdown]
# ##### Вывод: значения дисперсий уменьшаются с каждым слоем и более согласованы друг с другом для обоих методов иницилизаций

# %% [markdown]
# ##### У метода Xavier значения дисперсии при прямом проходе меньше чем у He, а при оборатном - наоборот, чуть больше

# %% [markdown]
# ##### Оба метода инициализации работают хорошо и справляются со своей задачей

# %% [markdown]
# ## Часть 2: DropConnect

# %% [markdown]
# #### 2.1 Реализуйте DropConnect по следующему шаблону: **(1 балл)**
#
# ![image.png](data:image/png;base64,...)

# %%
# полезная функция: .bernoulli_(p)
# не забывайте делать requires_grad=False у маски
# помните, что в вычислениях должны участвовать Variable, а не тензоры
class DropConnect(nn.Module):
    def __init__(self, input_dim, output_dim, p=0.5):
        super(DropConnect, self).__init__()
        self.linear = nn.Linear(input_dim, output_dim)
        self.p = p

    def forward(self, x):
        if self.training:
            mask = torch.ones_like(self.linear.weight).bernoulli_(1 - self.p)
            mask = Variable(mask, requires_grad=False)
        else:
            mask = Variable(torch.ones_like(self.linear.weight), requires_grad=False)

        mask = mask.data
        output = F.linear(x, self.linear.weight * mask, self.linear.bias)
        return output

# %%
class Dropout(nn.Module):
    def __init__(self, p=0.5):
        super(Dropout, self).__init__()
        self.p = p

    def forward(self, x):
        mask = torch.empty(x.shape).uniform_(0, 1).type(torch.FloatTensor)
        if self.training:
            mask = torch.where(mask > self.p, 1, 0)
        else:
            mask = torch.where(mask > self.p, 1, 1 - self.p)

        return x * mask

# %% [markdown]
# Основа для сети, которую будем обучать:

# %%
class TestNetwork(nn.Module):
    def __init__(self, final_part):
        super().__init__()

        channels = 1

        self.conv_layers = nn.Sequential(
            nn.Conv2d(channels, 2, 3, padding=1),
            nn.MaxPool2d(2),
            nn.ReLU(),
            nn.Conv2d(2, 4, 3, padding=1),
            nn.MaxPool2d(2),
            nn.ReLU(),
        )

        #input_size = 7 * 7 * 4 = 196
        self.flatten = nn.Flatten()

        self.final_part = final_part

        self.log_softmax = nn.LogSoftmax(1)

    def forward(self, x):
        x = self.conv_layers(x)
        x = self.flatten(x)
        x = self.final_part(x)
        return self.log_softmax(x)

# %% [markdown]
# #### DropConnect

# %%
layers = [
    DropConnect(196, 128),
    nn.ReLU(),
    DropConnect(128, 128),
    nn.ReLU(),
    DropConnect(128, 10)
]

# %%
network = TestNetwork(nn.Sequential(*layers))
optimizer = torch.optim.Adam(network.parameters(), lr=0.001)
loss_fn = torch.nn.NLLLoss()

# %%
dropconnect_losses = []
for epoch in range(10):
    network.train()
    for batch_idx, (images_train, labels_train) in enumerate(train_loader):
        optimizer.zero_grad()
        X = images_train.data
        y = labels_train.data
        output = network(X)
        loss = loss_fn(output, y)
        loss.backward()
        optimizer.step()

        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
            epoch, batch_idx * len(X), len(train_loader.dataset),
            100. * batch_idx / len(train_loader), loss.item()))

    network.eval()
    losses = []
    for batch_idx, (images_test, labels_test) in enumerate(test_loader):
        X = images_test.data
        y = labels_test.data
        output = network(X)
        loss = loss_fn(output, y)

        losses.append(loss.item())

    print('Test Epoch: {}\tLoss: {:.6f}'.format(
            epoch, np.mean(losses)))
    dropconnect_losses.append(np.mean(losses))
# Out:
# Train Epoch: 0 [0/60000 (0%)]	Loss: 2.300594
# Train Epoch: 0 [12800/60000 (21%)]	Loss: 1.631002
# Train Epoch: 0 [25600/60000 (43%)]	Loss: 0.965116
# Train Epoch: 0 [38400/60000 (64%)]	Loss: 0.798498
# Train Epoch: 0 [51200/60000 (85%)]	Loss: 0.588413
# Test Epoch: 0	Loss: 1.511399
# Train Epoch: 1 [0/60000 (0%)]	Loss: 0.646835
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 0.802496
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.499537
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.638006
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.518517
# Test Epoch: 1	Loss: 1.188243
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.428413
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.233778
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.457009
# Train Epoch: 2 [38400/60000 (64%)]	Loss: 0.242359
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.428310
# Test Epoch: 2	Loss: 0.810334
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.433050
# Train Epoch: 3 [12800/60000 (21%)]	Loss: 0.276471
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.267361
# Train Epoch: 3 [38400/60000 (64%)]	Loss: 0.364788
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.321305
# Test Epoch: 3	Loss: 0.706115
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.212359
# Train Epoch: 4 [12800/60000 (21%)]	Loss: 0.218889
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.147424
# Train Epoch: 4 [38400/60000 (64%)]	Loss: 0.326531
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.198837
# Test Epoch: 4	Loss: 0.679627
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.216023
# Train Epoch: 5 [12800/60000 (21%)]	Loss: 0.218466
# Train Epoch: 5 [25600/60000 (43%)]	Loss: 0.188066
# Train Epoch: 5 [38400/60000 (64%)]	Loss: 0.252893
# Train Epoch: 5 [51200/60000 (85%)]	Loss: 0.348146
# Test Epoch: 5	Loss: 0.586919
# Train Epoch: 6 [0/60000 (0%)]	Loss: 0.140785
# Train Epoch: 6 [12800/60000 (21%)]	Loss: 0.242549
# Train Epoch: 6 [25600/60000 (43%)]	Loss: 0.186954
# Train Epoch: 6 [38400/60000 (64%)]	Loss: 0.141144
# Train Epoch: 6 [51200/60000 (85%)]	Loss: 0.231250
# Test Epoch: 6	Loss: 0.560037
# Train Epoch: 7 [0/60000 (0%)]	Loss: 0.331625
# Train Epoch: 7 [12800/60000 (21%)]	Loss: 0.092775
# Train Epoch: 7 [25600/60000 (43%)]	Loss: 0.145369
# Train Epoch: 7 [38400/60000 (64%)]	Loss: 0.233975
# Train Epoch: 7 [51200/60000 (85%)]	Loss: 0.191241
# Test Epoch: 7	Loss: 0.528060
# Train Epoch: 8 [0/60000 (0%)]	Loss: 0.240661
# Train Epoch: 8 [12800/60000 (21%)]	Loss: 0.162366
# Train Epoch: 8 [25600/60000 (43%)]	Loss: 0.205040
# Train Epoch: 8 [38400/60000 (64%)]	Loss: 0.223960
# Train Epoch: 8 [51200/60000 (85%)]	Loss: 0.174185
# Test Epoch: 8	Loss: 0.455019
# Train Epoch: 9 [0/60000 (0%)]	Loss: 0.114151
# Train Epoch: 9 [12800/60000 (21%)]	Loss: 0.156083
# Train Epoch: 9 [25600/60000 (43%)]	Loss: 0.223319
# Train Epoch: 9 [38400/60000 (64%)]	Loss: 0.187610
# Train Epoch: 9 [51200/60000 (85%)]	Loss: 0.208407
# Test Epoch: 9	Loss: 0.444341

# %% [markdown]
# #### DropOut

# %%
layers = [
    nn.Linear(196, 128),
    nn.ReLU(),
    Dropout(),
    nn.Linear(128, 128),
    nn.ReLU(),
    Dropout(),
    nn.Linear(128, 10)
]

# %%
network = TestNetwork(nn.Sequential(*layers))
optimizer = torch.optim.Adam(network.parameters(), lr=0.001)
loss_fn = torch.nn.NLLLoss()

# %% [markdown]
# Обучим получившуюся сеть:

# %%
dropout_losses = []
for epoch in range(10):
    network.train()
    for batch_idx, (images_train, labels_train) in enumerate(train_loader):
        optimizer.zero_grad()
        X = images_train.data
        y = labels_train.data
        output = network(X)
        loss = loss_fn(output, y)
        loss.backward()
        optimizer.step()

        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
            epoch, batch_idx * len(X), len(train_loader.dataset),
            100. * batch_idx / len(train_loader), loss.item()))

    network.eval()
    losses = []
    for batch_idx, (images_test, labels_test) in enumerate(test_loader):
        X = images_test.data
        y = labels_test.data
        output = network(X)
        loss = loss_fn(output, y)

        losses.append(loss.item())

    print('Test Epoch: {}\tLoss: {:.6f}'.format(
            epoch, np.mean(losses)))
    dropout_losses.append(np.mean(losses))
# Out:
# Train Epoch: 0 [0/60000 (0%)]	Loss: 2.305769
# Train Epoch: 0 [12800/60000 (21%)]	Loss: 0.831448
# Train Epoch: 0 [25600/60000 (43%)]	Loss: 0.649729
# Train Epoch: 0 [38400/60000 (64%)]	Loss: 0.573008
# Train Epoch: 0 [51200/60000 (85%)]	Loss: 0.298046
# Test Epoch: 0	Loss: 0.300229
# Train Epoch: 1 [0/60000 (0%)]	Loss: 0.293975
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 0.271534
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.251994
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.244643
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.224450
# Test Epoch: 1	Loss: 0.207671
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.245437
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.356868
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.144000
# Train Epoch: 2 [38400/60000 (64%)]	Loss: 0.194504
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.285648
# Test Epoch: 2	Loss: 0.167214
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.163205
# Train Epoch: 3 [12800/60000 (21%)]	Loss: 0.175884
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.168710
# Train Epoch: 3 [38400/60000 (64%)]	Loss: 0.152985
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.249647
# Test Epoch: 3	Loss: 0.155999
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.214342
# Train Epoch: 4 [12800/60000 (21%)]	Loss: 0.077811
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.155973
# Train Epoch: 4 [38400/60000 (64%)]	Loss: 0.241732
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.182107
# Test Epoch: 4	Loss: 0.134258
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.105040
# Train Epoch: 5 [12800/60000 (21%)]	Loss: 0.157772
# Train Epoch: 5 [25600/60000 (43%)]	Loss: 0.118905
# Train Epoch: 5 [38400/60000 (64%)]	Loss: 0.144508
# Train Epoch: 5 [51200/60000 (85%)]	Loss: 0.221151
# Test Epoch: 5	Loss: 0.134245
# Train Epoch: 6 [0/60000 (0%)]	Loss: 0.108070
# Train Epoch: 6 [12800/60000 (21%)]	Loss: 0.106873
# Train Epoch: 6 [25600/60000 (43%)]	Loss: 0.203131
# Train Epoch: 6 [38400/60000 (64%)]	Loss: 0.056879
# Train Epoch: 6 [51200/60000 (85%)]	Loss: 0.139938
# Test Epoch: 6	Loss: 0.126869
# Train Epoch: 7 [0/60000 (0%)]	Loss: 0.193516
# Train Epoch: 7 [12800/60000 (21%)]	Loss: 0.175641
# Train Epoch: 7 [25600/60000 (43%)]	Loss: 0.104057
# Train Epoch: 7 [38400/60000 (64%)]	Loss: 0.094104
# Train Epoch: 7 [51200/60000 (85%)]	Loss: 0.084076
# Test Epoch: 7	Loss: 0.129131
# Train Epoch: 8 [0/60000 (0%)]	Loss: 0.185625
# Train Epoch: 8 [12800/60000 (21%)]	Loss: 0.117789
# Train Epoch: 8 [25600/60000 (43%)]	Loss: 0.157906
# Train Epoch: 8 [38400/60000 (64%)]	Loss: 0.222043
# Train Epoch: 8 [51200/60000 (85%)]	Loss: 0.036937
# Test Epoch: 8	Loss: 0.120505
# Train Epoch: 9 [0/60000 (0%)]	Loss: 0.059926
# Train Epoch: 9 [12800/60000 (21%)]	Loss: 0.121961
# Train Epoch: 9 [25600/60000 (43%)]	Loss: 0.146650
# Train Epoch: 9 [38400/60000 (64%)]	Loss: 0.244607
# Train Epoch: 9 [51200/60000 (85%)]	Loss: 0.283298
# Test Epoch: 9	Loss: 0.111028

# %% [markdown]
# #### Без регуляризации

# %%
layers = [
    nn.Linear(196, 128),
    nn.ReLU(),
    nn.Linear(128, 128),
    nn.ReLU(),
    nn.Linear(128, 10)
]

network = TestNetwork(nn.Sequential(*layers))
optimizer = torch.optim.Adam(network.parameters(), lr=0.001)
loss_fn = torch.nn.NLLLoss()

no_reg_losses = []
for epoch in range(10):
    network.train()
    for batch_idx, (images_train, labels_train) in enumerate(train_loader):
        optimizer.zero_grad()
        X = images_train.data
        y = labels_train.data
        output = network(X)
        loss = loss_fn(output, y)
        loss.backward()
        optimizer.step()

        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
            epoch, batch_idx * len(X), len(train_loader.dataset),
            100. * batch_idx / len(train_loader), loss.item()))

    network.eval()
    losses = []
    for batch_idx, (images_test, labels_test) in enumerate(test_loader):
        X = images_test.data
        y = labels_test.data
        output = network(X)
        loss = loss_fn(output, y)

        losses.append(loss.item())

    print('Test Epoch: {}\tLoss: {:.6f}'.format(
            epoch, np.mean(losses)))
    no_reg_losses.append(np.mean(losses))
# Out:
# Train Epoch: 0 [0/60000 (0%)]	Loss: 2.314241
# Train Epoch: 0 [12800/60000 (21%)]	Loss: 0.396918
# Train Epoch: 0 [25600/60000 (43%)]	Loss: 0.333990
# Train Epoch: 0 [38400/60000 (64%)]	Loss: 0.127353
# Train Epoch: 0 [51200/60000 (85%)]	Loss: 0.117803
# Test Epoch: 0	Loss: 0.135644
# Train Epoch: 1 [0/60000 (0%)]	Loss: 0.100732
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 0.142155
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.162524
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.069661
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.133606
# Test Epoch: 1	Loss: 0.092995
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.092113
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.088949
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.110792
# Train Epoch: 2 [38400/60000 (64%)]	Loss: 0.072038
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.065898
# Test Epoch: 2	Loss: 0.078342
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.075298
# Train Epoch: 3 [12800/60000 (21%)]	Loss: 0.087535
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.076436
# Train Epoch: 3 [38400/60000 (64%)]	Loss: 0.075242
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.108114
# Test Epoch: 3	Loss: 0.075359
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.092529
# Train Epoch: 4 [12800/60000 (21%)]	Loss: 0.043941
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.076997
# Train Epoch: 4 [38400/60000 (64%)]	Loss: 0.116543
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.035806
# Test Epoch: 4	Loss: 0.066589
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.132042
# Train Epoch: 5 [12800/60000 (21%)]	Loss: 0.056693
# Train Epoch: 5 [25600/60000 (43%)]	Loss: 0.074782
# Train Epoch: 5 [38400/60000 (64%)]	Loss: 0.053311
# Train Epoch: 5 [51200/60000 (85%)]	Loss: 0.077462
# Test Epoch: 5	Loss: 0.054956
# Train Epoch: 6 [0/60000 (0%)]	Loss: 0.071158
# Train Epoch: 6 [12800/60000 (21%)]	Loss: 0.021843
# Train Epoch: 6 [25600/60000 (43%)]	Loss: 0.013539
# Train Epoch: 6 [38400/60000 (64%)]	Loss: 0.126082
# Train Epoch: 6 [51200/60000 (85%)]	Loss: 0.043270
# Test Epoch: 6	Loss: 0.054867
# Train Epoch: 7 [0/60000 (0%)]	Loss: 0.033908
# Train Epoch: 7 [12800/60000 (21%)]	Loss: 0.009902
# Train Epoch: 7 [25600/60000 (43%)]	Loss: 0.034233
# Train Epoch: 7 [38400/60000 (64%)]	Loss: 0.041859
# Train Epoch: 7 [51200/60000 (85%)]	Loss: 0.092289
# Test Epoch: 7	Loss: 0.059384
# Train Epoch: 8 [0/60000 (0%)]	Loss: 0.052024
# Train Epoch: 8 [12800/60000 (21%)]	Loss: 0.010892
# Train Epoch: 8 [25600/60000 (43%)]	Loss: 0.070909
# Train Epoch: 8 [38400/60000 (64%)]	Loss: 0.032515
# Train Epoch: 8 [51200/60000 (85%)]	Loss: 0.052112
# Test Epoch: 8	Loss: 0.051515
# Train Epoch: 9 [0/60000 (0%)]	Loss: 0.040435
# Train Epoch: 9 [12800/60000 (21%)]	Loss: 0.056426
# Train Epoch: 9 [25600/60000 (43%)]	Loss: 0.013971
# Train Epoch: 9 [38400/60000 (64%)]	Loss: 0.015564
# Train Epoch: 9 [51200/60000 (85%)]	Loss: 0.075098
# Test Epoch: 9	Loss: 0.048394

# %% [markdown]
# #### 2.2 Сравните графики обучения нейроных сетей **(1 балл)**:
# 1. Свертки из TestNetwork -> 128 -> 128 -> 10 с ReLU и Dropout между всеми слоями
# 2. Свертки из TestNetwork -> 128 -> 128 -> 10 с ReLU и DropConnect вместо всех линейных слоев

# %%
plt.figure(figsize=(12, 10))
plt.plot(dropout_losses, label="Dropout")
plt.plot(dropconnect_losses, label="DropConnect")
#plt.plot(no_reg_losses, label="Без регуляризации")
plt.title("Графики изменения функции потерь для различных методов регуляризации")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# #### При использовании регуляризации DropConnect loss получается больше чем при Dropout

# %% [markdown]
# ### Часть 3: Batch Normalization

# %% [markdown]
# Наконец, давайте рассмотрим Batch Normalization. Этот слой вычитает среднее и делит на стандартное отклонение. Среднее и дисперсия вычисляются по батчу независимо для каждого нейрона. У этого слоя есть две важные проблемы: его нельзя использовать при обучении с размером батча 1 и он делает элементы батча зависимыми. Давайте реализуем аналог батч нормализации: <a href=https://arxiv.org/pdf/1607.06450.pdf>Layer normalization</a>. В layer normalization среднее и дисперсия вычисляются по активациям нейронов, независимо для каждого объекта.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### 3.1 Реализуйте Layer Normalization **(1 балл)**

# %%
# полезные функции: .std(dim), .mean(dim)

class LayerNormalization(nn.Module):
    def __init__(self, eps=1e-5):
        super(LayerNormalization, self).__init__()
        self.eps = eps  

    def forward(self, x):
        mean = x.mean(dim=-1, keepdim=True)
        std = x.std(dim=-1, keepdim=True)

        output = (x - mean) / (std + self.eps)

        return output

# %% [markdown]
# #### 3.2 Сравните графики обучения нейроных сетей **(1 балл)**:
# 1. Свертки из TestNetwork -> 128 -> 128 -> 10 с ReLU и Batch normalization между всеми слоями
# 2. Свертки из TestNetwork -> 128 -> 128 -> 10 с ReLU и Layer normalization между всеми слоями

# %%
layers = [
    nn.Linear(196, 128),
    nn.ReLU(),
    LayerNormalization(),  
    nn.Linear(128, 128),
    nn.ReLU(),
    LayerNormalization(),  
    nn.Linear(128, 10)
]

network = TestNetwork(nn.Sequential(*layers))
optimizer = torch.optim.Adam(network.parameters(), lr=0.001)
loss_fn = torch.nn.NLLLoss()

layer_losses = []
for epoch in range(10):
    network.train()
    for batch_idx, (images_train, labels_train) in enumerate(train_loader):
        optimizer.zero_grad()
        X = images_train.data
        y = labels_train.data
        output = network(X)
        loss = loss_fn(output, y)
        loss.backward()
        optimizer.step()

        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
            epoch, batch_idx * len(X), len(train_loader.dataset),
            100. * batch_idx / len(train_loader), loss.item()))

    network.eval()
    losses = []
    for batch_idx, (images_test, labels_test) in enumerate(test_loader):
        X = images_test.data
        y = labels_test.data
        output = network(X)
        loss = loss_fn(output, y)

        losses.append(loss.item())

    print('Test Epoch: {}\tLoss: {:.6f}'.format(
            epoch, np.mean(losses)))
    layer_losses.append(np.mean(losses))
# Out:
# Train Epoch: 0 [0/60000 (0%)]	Loss: 2.552029
# Train Epoch: 0 [12800/60000 (21%)]	Loss: 0.315333
# Train Epoch: 0 [25600/60000 (43%)]	Loss: 0.227456
# Train Epoch: 0 [38400/60000 (64%)]	Loss: 0.096778
# Train Epoch: 0 [51200/60000 (85%)]	Loss: 0.117251
# Test Epoch: 0	Loss: 0.103141
# Train Epoch: 1 [0/60000 (0%)]	Loss: 0.089339
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 0.126093
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.110510
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.029984
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.078629
# Test Epoch: 1	Loss: 0.082487
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.053144
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.048720
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.084306
# Train Epoch: 2 [38400/60000 (64%)]	Loss: 0.115873
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.065989
# Test Epoch: 2	Loss: 0.069132
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.088270
# Train Epoch: 3 [12800/60000 (21%)]	Loss: 0.034969
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.037111
# Train Epoch: 3 [38400/60000 (64%)]	Loss: 0.027855
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.070064
# Test Epoch: 3	Loss: 0.060974
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.033632
# Train Epoch: 4 [12800/60000 (21%)]	Loss: 0.036515
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.024462
# Train Epoch: 4 [38400/60000 (64%)]	Loss: 0.049061
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.026641
# Test Epoch: 4	Loss: 0.062298
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.024614
# Train Epoch: 5 [12800/60000 (21%)]	Loss: 0.009653
# Train Epoch: 5 [25600/60000 (43%)]	Loss: 0.085431
# Train Epoch: 5 [38400/60000 (64%)]	Loss: 0.055356
# Train Epoch: 5 [51200/60000 (85%)]	Loss: 0.006121
# Test Epoch: 5	Loss: 0.057910
# Train Epoch: 6 [0/60000 (0%)]	Loss: 0.040004
# Train Epoch: 6 [12800/60000 (21%)]	Loss: 0.005631
# Train Epoch: 6 [25600/60000 (43%)]	Loss: 0.013199
# Train Epoch: 6 [38400/60000 (64%)]	Loss: 0.047136
# Train Epoch: 6 [51200/60000 (85%)]	Loss: 0.025425
# Test Epoch: 6	Loss: 0.065467
# Train Epoch: 7 [0/60000 (0%)]	Loss: 0.028223
# Train Epoch: 7 [12800/60000 (21%)]	Loss: 0.035946
# Train Epoch: 7 [25600/60000 (43%)]	Loss: 0.009765
# Train Epoch: 7 [38400/60000 (64%)]	Loss: 0.012010
# Train Epoch: 7 [51200/60000 (85%)]	Loss: 0.040558
# Test Epoch: 7	Loss: 0.060274
# Train Epoch: 8 [0/60000 (0%)]	Loss: 0.039074
# Train Epoch: 8 [12800/60000 (21%)]	Loss: 0.035401
# Train Epoch: 8 [25600/60000 (43%)]	Loss: 0.006282
# Train Epoch: 8 [38400/60000 (64%)]	Loss: 0.069812
# Train Epoch: 8 [51200/60000 (85%)]	Loss: 0.019580
# Test Epoch: 8	Loss: 0.065341
# Train Epoch: 9 [0/60000 (0%)]	Loss: 0.039326
# Train Epoch: 9 [12800/60000 (21%)]	Loss: 0.013391
# Train Epoch: 9 [25600/60000 (43%)]	Loss: 0.011678
# Train Epoch: 9 [38400/60000 (64%)]	Loss: 0.044908
# Train Epoch: 9 [51200/60000 (85%)]	Loss: 0.010051
# Test Epoch: 9	Loss: 0.061068

# %%
layers = [
    nn.Linear(196, 128),
    nn.ReLU(),
    nn.BatchNorm1d(128), 
    nn.Linear(128, 128),
    nn.ReLU(),
    nn.BatchNorm1d(128), 
    nn.Linear(128, 10)
]

network = TestNetwork(nn.Sequential(*layers))
optimizer = torch.optim.Adam(network.parameters(), lr=0.001)
loss_fn = torch.nn.NLLLoss()

batch_losses = []
for epoch in range(10):
    network.train()
    for batch_idx, (images_train, labels_train) in enumerate(train_loader):
        optimizer.zero_grad()
        X = images_train.data
        y = labels_train.data
        output = network(X)
        loss = loss_fn(output, y)
        loss.backward()
        optimizer.step()

        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
            epoch, batch_idx * len(X), len(train_loader.dataset),
            100. * batch_idx / len(train_loader), loss.item()))

    network.eval()
    losses = []
    for batch_idx, (images_test, labels_test) in enumerate(test_loader):
        X = images_test.data
        y = labels_test.data
        output = network(X)
        loss = loss_fn(output, y)

        losses.append(loss.item())

    print('Test Epoch: {}\tLoss: {:.6f}'.format(
            epoch, np.mean(losses)))
    batch_losses.append(np.mean(losses))
# Out:
# Train Epoch: 0 [0/60000 (0%)]	Loss: 2.369814
# Train Epoch: 0 [12800/60000 (21%)]	Loss: 0.267007
# Train Epoch: 0 [25600/60000 (43%)]	Loss: 0.174554
# Train Epoch: 0 [38400/60000 (64%)]	Loss: 0.154064
# Train Epoch: 0 [51200/60000 (85%)]	Loss: 0.229469
# Test Epoch: 0	Loss: 0.085741
# Train Epoch: 1 [0/60000 (0%)]	Loss: 0.095158
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 0.059624
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.155656
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.066705
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.051257
# Test Epoch: 1	Loss: 0.075675
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.052406
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.075463
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.111895
# Train Epoch: 2 [38400/60000 (64%)]	Loss: 0.025758
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.092420
# Test Epoch: 2	Loss: 0.063989
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.083378
# Train Epoch: 3 [12800/60000 (21%)]	Loss: 0.036083
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.060869
# Train Epoch: 3 [38400/60000 (64%)]	Loss: 0.026474
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.094051
# Test Epoch: 3	Loss: 0.060946
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.049329
# Train Epoch: 4 [12800/60000 (21%)]	Loss: 0.056073
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.028492
# Train Epoch: 4 [38400/60000 (64%)]	Loss: 0.028956
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.031276
# Test Epoch: 4	Loss: 0.058297
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.043127
# Train Epoch: 5 [12800/60000 (21%)]	Loss: 0.065734
# Train Epoch: 5 [25600/60000 (43%)]	Loss: 0.009076
# Train Epoch: 5 [38400/60000 (64%)]	Loss: 0.048379
# Train Epoch: 5 [51200/60000 (85%)]	Loss: 0.093875
# Test Epoch: 5	Loss: 0.055727
# Train Epoch: 6 [0/60000 (0%)]	Loss: 0.045526
# Train Epoch: 6 [12800/60000 (21%)]	Loss: 0.018379
# Train Epoch: 6 [25600/60000 (43%)]	Loss: 0.049709
# Train Epoch: 6 [38400/60000 (64%)]	Loss: 0.179130
# Train Epoch: 6 [51200/60000 (85%)]	Loss: 0.069291
# Test Epoch: 6	Loss: 0.052249
# Train Epoch: 7 [0/60000 (0%)]	Loss: 0.049953
# Train Epoch: 7 [12800/60000 (21%)]	Loss: 0.013944
# Train Epoch: 7 [25600/60000 (43%)]	Loss: 0.075209
# Train Epoch: 7 [38400/60000 (64%)]	Loss: 0.099444
# Train Epoch: 7 [51200/60000 (85%)]	Loss: 0.007857
# Test Epoch: 7	Loss: 0.044982
# Train Epoch: 8 [0/60000 (0%)]	Loss: 0.020577
# Train Epoch: 8 [12800/60000 (21%)]	Loss: 0.020949
# Train Epoch: 8 [25600/60000 (43%)]	Loss: 0.002091
# Train Epoch: 8 [38400/60000 (64%)]	Loss: 0.026632
# Train Epoch: 8 [51200/60000 (85%)]	Loss: 0.014044
# Test Epoch: 8	Loss: 0.052415
# Train Epoch: 9 [0/60000 (0%)]	Loss: 0.040918
# Train Epoch: 9 [12800/60000 (21%)]	Loss: 0.021435
# Train Epoch: 9 [25600/60000 (43%)]	Loss: 0.025206
# Train Epoch: 9 [38400/60000 (64%)]	Loss: 0.023853
# Train Epoch: 9 [51200/60000 (85%)]	Loss: 0.027593
# Test Epoch: 9	Loss: 0.057825

# %%
plt.figure(figsize=(12, 10))
plt.plot(layer_losses, label="Layer normalization")
plt.plot(batch_losses, label="Batch normalization")
plt.title("Графики изменения функции потерь для различных методов нормализации")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ##### После применения методов нормализации модели имеют меньший loss, чем после применения регуляризации

# %% [markdown]
# ##### При нормализации Layer norm, loss чуть больше чем при применении Batch norm
